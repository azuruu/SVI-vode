# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
fp = "cb_2018_us_state_500k.shp"
map_df = gpd.read_file(fp)
# check the GeoDataframe
map_df
# Out:
#    STATEFP   STATENS     AFFGEOID GEOID STUSPS  \
# 0       28  01779790  0400000US28    28     MS
# 1       37  01027616  0400000US37    37     NC
# 2       40  01102857  0400000US40    40     OK
# 3       51  01779803  0400000US51    51     VA
# 4       54  01779805  0400000US54    54     WV
# 5       22  01629543  0400000US22    22     LA
# 6       26  01779789  0400000US26    26     MI
# 7       25  00606926  0400000US25    25     MA
# 8       16  01779783  0400000US16    16     ID
# 9       12  00294478  0400000US12    12     FL
# 10      31  01779792  0400000US31    31     NE
# 11      53  01779804  0400000US53    53     WA
# 12      35  00897535  0400000US35    35     NM
# 13      72  01779808  0400000US72    72     PR
# 14      46  01785534  0400000US46    46     SD
# 15      48  01779801  0400000US48    48     TX
# 16      06  01779778  0400000US06    06     CA
# 17      01  01779775  0400000US01    01     AL
# 18      13  01705317  0400000US13    13     GA
# ...

# %%
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.rcParams['figure.figsize'] = [50, 70] #height, width
map_df.plot()
# Out:
# <AxesSubplot:>

# %%
province = pd.read_csv("rpl2018corrected.csv")
province.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     NAME   COUNTY  E_TOTPOP  RPL_THEMES
# 0           0             0  Alabama  Autauga      1923      0.2533
# 1           1             1  Alabama  Autauga      3476      0.6400
# 2           2             2  Alabama  Autauga      9883      0.4713
# 3           3             3  Alabama  Autauga      2826      0.2025
# 4           4             4  Alabama  Autauga     11603      0.5260

# %%
# join the geodataframe with the csv dataframe
merged = map_df.merge(province, how='left', left_on="NAME", right_on="NAME")
merged = merged[['NAME', 'geometry', 'E_TOTPOP', 'RPL_THEMES']]
merged.head()
# Out:
#           NAME                                           geometry  E_TOTPOP  \
# 0  Mississippi  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...    2896.0
# 1  Mississippi  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...    3630.0
# 2  Mississippi  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...    3080.0
# 3  Mississippi  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...    3649.0
# 4  Mississippi  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...    5691.0
#
#    RPL_THEMES
# 0      0.9850
# 1      0.9018
# 2      0.7369
# 3      0.6069
# 4      0.5286

# %%
# set the value column that will be visualised
variable = 'RPL_THEMES'
# set the range for the choropleth values
vmin, vmax = 0, 1
# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(30, 10))
# remove the axis
ax.axis('off')
# add a title and annotation
ax.set_title('# of Cities per each Region', fontdict={'fontsize': '25', 'fontweight' : '3'})
ax.annotate('Source: Wikipedia - https://en.wikipedia.org/wiki/Provinces_of_Indonesia', xy=(0.6, .05), xycoords='figure fraction', fontsize=12, color='#555555')
# Create colorbar legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
# empty array for the data range
sm.set_array([]) # or alternatively sm._A = []. Not sure why this step is necessary, but many recommends it
# add the colorbar to the figure
fig.colorbar(sm)
# create map
merged.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8')
# Out:
# <AxesSubplot:title={'center':'# of Cities per each Region'}>

# %%
map_df.loc[15, "geometry"]
